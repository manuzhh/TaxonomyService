# %%
#################################################
# Importing TenKGnad texts and preprocessing them
#################################################

# %%
# restarting the kernel
from IPython.core.display import HTML
HTML("<script>Jupyter.notebook.kernel.restart()</script>")
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
# imports
from CorpusImporter import CorpusImporter
from Storage import Storage
from SessionLogger import SessionLogger
from TextPreprocessor import TextPreprocessor
from StopwordDownloaderNLTK import StopwordDownloaderNLTK
# Out:
# Using TensorFlow backend.

# %%
# Before proceeding, please, make sure to setup the directory structure as specified in the documentation

# %%
# Clearing data folder contents from session
Storage.delete_session_data()
# Clearing log file from session
SessionLogger.clear()

# %%
# Starting the import
identifier = CorpusImporter.import_docs()
identifier
# Out:
# 'tenkgnad'

# %%
df = Storage.load_pd_frame(identifier)
df
# Out:
#            categories                                               text
# 0              [Etat]  Die ARD-Tochter Degeto hat sich verpflichtet, ...
# 1              [Etat]  App sei nicht so angenommen worden wie geplant...
# 2              [Etat]  Zum Welttag der Suizidprävention ist es Zeit, ...
# 3              [Etat]  Mitarbeiter überreichten Eigentümervertretern ...
# 4              [Etat]  Service: Jobwechsel in der Kommunikationsbranc...
# ...               ...                                                ...
# 10268  [Wissenschaft]  Die Fundstelle in Südengland ist Unesco-Weltku...
# 10269  [Wissenschaft]  Im Team arbeitet auch ein Inspektor der sudane...
# 10270  [Wissenschaft]  Die zentrale Frage des Projekts: Siedelten Ägy...
# 10271  [Wissenschaft]  Klimatische Verschlechterungen dürften zur Auf...
# 10272  [Wissenschaft]  Knochen können zum Verständnis des Lebens in d...
#
# [10273 rows x 2 columns]

# %%
# Preprocessing...
# Download and store stopwords from NLTK
StopwordDownloaderNLTK.get_stopwords()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/m.zimmermann/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# {'aber',
#  'alle',
#  'allem',
#  'allen',
#  'aller',
#  'alles',
#  'als',
#  'also',
#  'am',
#  'an',
#  'ander',
#  'andere',
#  'anderem',
#  'anderen',
#  'anderer',
#  'anderes',
#  'anderm',
#  'andern',
#  'anderr',
#  'anders',
#  'auch',
#  'auf',
#  'aus',
#  'bei',
#  'bin',
#  'bis',
#  'bist',
#  'da',
#  'damit',
#  'dann',
#  'das',
#  'dass',
#  'dasselbe',
#  'dazu',
#  'daß',
#  'dein',
#  'deine',
#  'deinem',
#  'deinen',
#  'deiner',
#  'deines',
#  'dem',
#  'demselben',
#  'den',
#  'denn',
#  'denselben',
#  'der',
#  'derer',
#  'derselbe',
#  'derselben',
#  'des',
#  'desselben',
#  'dessen',
#  'dich',
#  'die',
#  'dies',
#  'diese',
#  'dieselbe',
#  'dieselben',
#  'diesem',
#  'diesen',
#  'dieser',
#  'dieses',
#  'dir',
#  'doch',
#  'dort',
#  'du',
#  'durch',
#  'ein',
#  'eine',
# ...

# %%
# Do the preprocessing. This step may take a few minutes
df = TextPreprocessor.preprocess_texts(df, storage_level=2, storage_name=identifier)
df
# Out:
#            categories                                               text  \
# 0              [Etat]  Die ARD-Tochter Degeto hat sich verpflichtet, ...
# 1              [Etat]  App sei nicht so angenommen worden wie geplant...
# 2              [Etat]  Zum Welttag der Suizidprävention ist es Zeit, ...
# 3              [Etat]  Mitarbeiter überreichten Eigentümervertretern ...
# 4              [Etat]  Service: Jobwechsel in der Kommunikationsbranc...
# ...               ...                                                ...
# 10268  [Wissenschaft]  Die Fundstelle in Südengland ist Unesco-Weltku...
# 10269  [Wissenschaft]  Im Team arbeitet auch ein Inspektor der sudane...
# 10270  [Wissenschaft]  Die zentrale Frage des Projekts: Siedelten Ägy...
# 10271  [Wissenschaft]  Klimatische Verschlechterungen dürften zur Auf...
# 10272  [Wissenschaft]  Knochen können zum Verständnis des Lebens in d...
#
#                                            noise removed  \
# ...

# %%
df = Storage.load_pd_frame('tenkgnad_noiseRemoved')
df
# Out:
#            categories                                               text  \
# 0              [Etat]  Die ARD-Tochter Degeto hat sich verpflichtet, ...
# 1              [Etat]  App sei nicht so angenommen worden wie geplant...
# 2              [Etat]  Zum Welttag der Suizidprävention ist es Zeit, ...
# 3              [Etat]  Mitarbeiter überreichten Eigentümervertretern ...
# 4              [Etat]  Service: Jobwechsel in der Kommunikationsbranc...
# ...               ...                                                ...
# 10268  [Wissenschaft]  Die Fundstelle in Südengland ist Unesco-Weltku...
# 10269  [Wissenschaft]  Im Team arbeitet auch ein Inspektor der sudane...
# 10270  [Wissenschaft]  Die zentrale Frage des Projekts: Siedelten Ägy...
# 10271  [Wissenschaft]  Klimatische Verschlechterungen dürften zur Auf...
# 10272  [Wissenschaft]  Knochen können zum Verständnis des Lebens in d...
#
#                                            noise removed
# ...

# %%
df = Storage.load_pd_frame('tenkgnad_stopwordsRemoved')
df
# Out:
#            categories                                               text  \
# 0              [Etat]  Die ARD-Tochter Degeto hat sich verpflichtet, ...
# 1              [Etat]  App sei nicht so angenommen worden wie geplant...
# 2              [Etat]  Zum Welttag der Suizidprävention ist es Zeit, ...
# 3              [Etat]  Mitarbeiter überreichten Eigentümervertretern ...
# 4              [Etat]  Service: Jobwechsel in der Kommunikationsbranc...
# ...               ...                                                ...
# 10268  [Wissenschaft]  Die Fundstelle in Südengland ist Unesco-Weltku...
# 10269  [Wissenschaft]  Im Team arbeitet auch ein Inspektor der sudane...
# 10270  [Wissenschaft]  Die zentrale Frage des Projekts: Siedelten Ägy...
# 10271  [Wissenschaft]  Klimatische Verschlechterungen dürften zur Auf...
# 10272  [Wissenschaft]  Knochen können zum Verständnis des Lebens in d...
#
#                                            noise removed  \
# ...

# %%
df = Storage.load_pd_frame('tenkgnad_lemmatized')
df
# Out:
#            categories                                               text  \
# 0              [Etat]  Die ARD-Tochter Degeto hat sich verpflichtet, ...
# 1              [Etat]  App sei nicht so angenommen worden wie geplant...
# 2              [Etat]  Zum Welttag der Suizidprävention ist es Zeit, ...
# 3              [Etat]  Mitarbeiter überreichten Eigentümervertretern ...
# 4              [Etat]  Service: Jobwechsel in der Kommunikationsbranc...
# ...               ...                                                ...
# 10268  [Wissenschaft]  Die Fundstelle in Südengland ist Unesco-Weltku...
# 10269  [Wissenschaft]  Im Team arbeitet auch ein Inspektor der sudane...
# 10270  [Wissenschaft]  Die zentrale Frage des Projekts: Siedelten Ägy...
# 10271  [Wissenschaft]  Klimatische Verschlechterungen dürften zur Auf...
# 10272  [Wissenschaft]  Knochen können zum Verständnis des Lebens in d...
#
#                                            noise removed  \
# ...
